# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/Aesthetic-graphs/blob/main/Olive%20Blossom%20Palette.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Olive Blossom Palette*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# *copy it:*

# %%
def set_olive_blossom_theme():
    """Presentation style – Olive Blossom Palette"""
    palette = ["#A3A380",  # Olive Petal
               "#D7CE93",  # Golden Clover
               "#EFEBCE",  # Arctic Daisy
               "#D8A48F",  # Rose Blush
               "#BB8588"]  # Peach Blossom

    sns.set_theme(
        style="whitegrid",
        rc={
            "axes.spines.top": False,
            "axes.spines.right": False,
            "axes.titlesize": 14,
            "axes.labelsize": 12,
            "grid.alpha": 0.2,
            "figure.dpi": 120,
            "savefig.dpi": 150,
        }
    )
    sns.set_palette(palette)
    return palette

# set style
palette = set_olive_blossom_theme()

# %%
np.random.seed(42)
x_train = np.random.normal(0, 1, 300)
y_train = 15 * x_train + np.random.normal(0, 10, 300)

x_test = np.random.normal(0.5, 1, 100)
y_test = 15 * x_test + np.random.normal(0, 10, 100)

coef = np.polyfit(x_train, y_train, 1)
line_x = np.linspace(-3, 4, 100)
line_y = coef[0] * line_x + coef[1]

plt.figure(figsize=(8, 5))
plt.scatter(x_train, y_train, alpha=0.7, color=palette[0], label="Training set")
plt.scatter(x_test, y_test, alpha=0.7, color=palette[1], label="Test set")
plt.plot(line_x, line_y, color=palette[2], linewidth=2.5, label="Regression line")

plt.xlabel("Feature x")
plt.ylabel("Target variable")
plt.title("Presentation Scatterplot – Olive Blossom Style 🌿🌸")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127807 (\N{HERB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127800 (\N{CHERRY BLOSSOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
np.random.seed(42)
x_train = np.random.normal(0, 1, 300)
y_train = 15 * x_train + np.random.normal(0, 10, 300)

x_test = np.random.normal(0.5, 1, 100)
y_test = 15 * x_test + np.random.normal(0, 10, 100)

coef = np.polyfit(x_train, y_train, 1)
line_x = np.linspace(-3, 4, 100)
line_y = coef[0] * line_x + coef[1]

plt.figure(figsize=(8, 5))
plt.scatter(x_train, y_train, alpha=0.8, color=palette[3], label="Training set")
plt.scatter(x_test, y_test, alpha=0.8, color=palette[4], label="Test set")

plt.xlabel("Feature x")
plt.ylabel("Target variable")
plt.title("Presentation Scatterplot – Olive Blossom Style 🌿🌸")
plt.legend()
plt.show()
